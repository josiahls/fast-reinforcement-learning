# %% [markdown]
# ## Interpreter Demo

# %%
import gym
import numpy as np

from fast_rl.agents.DQN import DQN
from fast_rl.core.Learner import AgentLearner
from fast_rl.core.MarkovDecisionProcess import MDPDataBunchAlpha, MDPDatasetAlpha
from fast_rl.core.Interpreter import AgentInterpretationAlpha
# %matplotlib inline
    
data = MDPDataBunchAlpha.from_env('CartPole-v1', render='human', bs=64)
model = DQN(data)
learn = AgentLearner(data, model)

learn.fit(5)
# Out:
# pygame 2.0.0.dev3 (SDL 2.0.9, python 3.6.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.536473</td>
#       <td>0.538813</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.536959</td>
#       <td>0.537589</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.536376</td>
#       <td>0.535369</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.535773</td>
#       <td>0.534410</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.536761</td>
#       <td>0.539852</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.to_pickle()

# %%
data = MDPDataBunchAlpha.from_pickle('CartPole-v1', render='human', bs=64)
model = DQN(data)
learn = AgentLearner(data, model)

# %%
interp = AgentInterpretationAlpha(learn)
interp.plot_q_density()
# Out:
# 0.1222222222222222 1.3222222222222224 -1.4745813310146332 -0.2745814025402069

# %%
interp.plot_episode(1)

# %%
interp.plot_rewards_over_iterations(1)

# %%
interp.plot_rewards_over_iterations(cumulative=True)

# %%
interp.plot_rewards_over_episodes(cumulative=False)

# %%
interp.plot_rewards_over_episodes(cumulative=True)

# %%
interp.iplot_episode(episode=1, fps=1)
interp.current_animation.ipython_display(fps=1, loop=True, autoplay=True)
# Out:
# t:   0%|          | 0/9 [00:00<?, ?it/s, now=None]
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# t:   0%|          | 0/9 [00:00<?, ?it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video loop='True' autoplay='True'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
